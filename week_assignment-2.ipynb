# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('datasets/fb.csv')

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
#1

# %%
df['Paid'].value_counts()
# Out:
# Paid
# 0.0    360
# 1.0    139
# Name: count, dtype: int64

# %%
# 2

# %%
df = df[['Type','Post Month','like','comment','share']]

# %%
df
# Out:
#        Type  Post Month    like  comment  share
# 0     Photo          12    79.0        4   17.0
# 1    Status          12   130.0        5   29.0
# 2     Photo          12    66.0        0   14.0
# 3     Photo          12  1572.0       58  147.0
# 4     Photo          12   325.0       19   49.0
# ..      ...         ...     ...      ...    ...
# 495   Photo           1    53.0        5   26.0
# 496   Photo           1    53.0        0   22.0
# 497   Photo           1    93.0        4   18.0
# 498   Photo           1    91.0        7   38.0
# 499   Photo           1    91.0        0   28.0
#
# [500 rows x 5 columns]

# %%
#3

# %%
x = df[(df['Post Month']==9)]
x
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 155            135700   Photo         2           9             3          7
# 156            135700   Photo         2           9             2         11
# 157            135700   Photo         3           9             2          2
# 158            135700   Photo         2           9             1         10
# 159            135617   Photo         2           9             1          3
# 160            135617   Photo         3           9             7          9
# 161            135617   Photo         2           9             7          3
# 162            135617   Photo         3           9             6         10
# 163            135617  Status         2           9             6          4
# 164            135428   Photo         1           9             5         10
# 165            135428   Photo         2           9             5          3
# ...

# %%
x['Page total likes'].mean()
# Out:
# 135185.33333333334

# %%
#4

# %%
y = df['Type']== "Link"
y
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: Type, Length: 500, dtype: bool

# %%
total_true = y.sum()
print("Total Link values:", total_true)
# Out:
# Total Link values: 22

# %%
#5

# %%
mask = df['Type'] == "video"
mask
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: Type, Length: 500, dtype: bool

# %%
df1 = df[mask]

# %%
df1['share'].sum()
# Out:
# 0.0

# %%
df['Post Hour'].max()
# Out:
# 23

# %%
y= df[df['Post Hour'] == 23]
y
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 230            131630  Photo         3           7             2         23
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 230   0.0                       2822                             5058
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# 230                     424                      351
#
#      Lifetime Post Consumptions  \
# 230                         486
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 230                                               3681
#
#      Lifetime Post reach by people who like your Page  \
# 230                                              2020
#
#      Lifetime People who have liked your Page and engaged with your post  \
# 230                                                327
#
#      comment   like  share  Total Interactions
# 230        2  113.0   20.0                 135
