# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0,100,0.5)

# %%
y = np.sin(x)

# %%
plt.figure(figsize =(16,9))
plt.plot(x, y)

# %%
x = np.arange(0,100,0.5)

# %%
y = np.cos(x)

# %%
plt.figure(figsize =(16,9))
plt.plot(x, y)

# %%
import cv2
# Load the image
image = cv2.imread('images/lenna.png')

# rotate the image 180 deg CLOCK WISE
rotated_image = cv2.rotate(image, cv2.ROTATE_180)

# SHOW THWE ROTATED IMAGE
cv2.imshow('Rotated image', rotated_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
# Load the image
image = cv2.imread('images/lenna.png')

# rotate the image 90 deg CLOCK WISE
rotated_image = cv2.rotate(image, cv2.ROTATE_90_CLOCKWISE)

# SHOW THWE ROTATED IMAGE
cv2.imshow('Rotated image', rotated_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
# Load the image
image = cv2.imread('images/lenna.png')

# Define the centre point and rotate angle
center = (image.shape[1] // 2, image.shape[0] // 2)
angle = -60
#create rotation matrix
rotated_matrix = cv2.getRotationMatrix2D(center, angle, 1.0)

#apply the rotation using warpAffine
rotated_image = cv2.warpAffine(image, rotated_matrix,(image.shape[1], image.shape[0]))


# SHOW THWE ROTATED IMAGE
cv2.imshow('Rotated image', rotated_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
rotated_matrix
# Out:
# array([[  0.5       ,  -0.8660254 , 349.70250337],
#        [  0.8660254 ,   0.5       , -93.70250337]])

# %%
import cv2
# Load the image
image = cv2.imread('images/lenna.png')

# Define the centre point and rotate angle
center = (image.shape[1] // 2, image.shape[0] // 2)
angle = -60
#create rotation matrix
rotated_matrix = cv2.getRotationMatrix2D((100,100), angle, 1.0)

#apply the rotation using warpAffine
rotated_image = cv2.warpAffine(image, rotated_matrix,(image.shape[1], image.shape[0]))


# SHOW THWE ROTATED IMAGE
cv2.imshow('Rotated image', rotated_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # rotate using PILLO

# %%
from PIL import Image
# Load the image
image = Image.open('images/lenna.png')

# %%
converted_img = image.transpose(Image.ROTATE_180)
converted_img
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
