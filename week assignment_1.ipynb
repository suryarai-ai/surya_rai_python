# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('datasets/airquality.csv')

# %%
df
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0             1   41.0    190.0   7.4    67      5    1
# 1             2   36.0    118.0   8.0    72      5    2
# 2             3   12.0    149.0  12.6    74      5    3
# 3             4   18.0    313.0  11.5    62      5    4
# 4             5    NaN      NaN  14.3    56      5    5
# ..          ...    ...      ...   ...   ...    ...  ...
# 148         149   30.0    193.0   6.9    70      9   26
# 149         150    NaN    145.0  13.2    77      9   27
# 150         151   14.0    191.0  14.3    75      9   28
# 151         152   18.0    131.0   8.0    76      9   29
# 152         153   20.0    223.0  11.5    68      9   30
#
# [153 rows x 7 columns]

# %%
df.shape
# Out:
# (153, 7)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Ozone', 'Solar.R', 'Wind', 'Temp', 'Month', 'Day'], dtype='object')

# %%
x = df.iloc[10:25,:] #10 to 25 row and all column
x
# Out:
#     Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 10          11    7.0      NaN   6.9    74      5   11
# 11          12   16.0    256.0   9.7    69      5   12
# 12          13   11.0    290.0   9.2    66      5   13
# 13          14   14.0    274.0  10.9    68      5   14
# 14          15   18.0     65.0  13.2    58      5   15
# 15          16   14.0    334.0  11.5    64      5   16
# 16          17   34.0    307.0  12.0    66      5   17
# 17          18    6.0     78.0  18.4    57      5   18
# 18          19   30.0    322.0  11.5    68      5   19
# 19          20   11.0     44.0   9.7    62      5   20
# 20          21    1.0      8.0   9.7    59      5   21
# 21          22   11.0    320.0  16.6    73      5   22
# 22          23    4.0     25.0   9.7    61      5   23
# 23          24   32.0     92.0  12.0    61      5   24
# 24          25    NaN     66.0  16.6    57      5   25

# %%
df2= df.sort_values('Temp')
df2
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 4             5    NaN      NaN  14.3    56      5    5
# 17           18    6.0     78.0  18.4    57      5   18
# 24           25    NaN     66.0  16.6    57      5   25
# 26           27    NaN      NaN   8.0    57      5   27
# 14           15   18.0     65.0  13.2    58      5   15
# ..          ...    ...      ...   ...   ...    ...  ...
# 41           42    NaN    259.0  10.9    93      6   11
# 122         123   85.0    188.0   6.3    94      8   31
# 120         121  118.0    225.0   2.3    94      8   29
# 121         122   84.0    237.0   6.3    96      8   30
# 119         120   76.0    203.0   9.7    97      8   28
#
# [153 rows x 7 columns]

# %%
#df['Temp']= 5/9(df['Temp']- 32)
df['Temp_Celsius'] = 5/9 * (df['Temp'] - 32)

# %%
df['Month'] = df['Month']=5
df
# Out:
#    sr.no           name  matches  runs  catches  wickets  stumpings  Month
# 0      1    Anil Dalpat      122  6755       56       12          0      5
# 1      2   Rohan Kanhay      144  1256       76      178          0      5
# 2      3  Avdhoot Dighe      265  8954      120        0          0      5
# 3      4       Bahubali       10   756        6       11          3      5
# 4      5      Leeladhar      234  2866      105      376          0      5
# 5      6      Pradyumna      177  5877       47      122          0      5
# 6      7     Dinesh Roy      211  8537      112       16          0      5
# 7      8     Parmeshwar      245  9466       53        0          0      5
# 8      9    Ali Durrani       55  2756       12       26          0      5
# 9     10   Litesh Singh       89  1099       46       49          0      5

# %% [markdown]
# # cricket.csv

# %%
df = pd.read_csv('datasets/cricket.csv')
df
# Out:
#    sr.no           name  matches  runs  catches  wickets  stumpings
# 0      1    Anil Dalpat      122  6755       56       12          0
# 1      2   Rohan Kanhay      144  1256       76      178          0
# 2      3  Avdhoot Dighe      265  8954      120        0          0
# 3      4       Bahubali       10   756        6       11          3
# 4      5      Leeladhar      234  2866      105      376          0
# 5      6      Pradyumna      177  5877       47      122          0
# 6      7     Dinesh Roy      211  8537      112       16          0
# 7      8     Parmeshwar      245  9466       53        0          0
# 8      9    Ali Durrani       55  2756       12       26          0
# 9     10   Litesh Singh       89  1099       46       49          0

# %%
df.shape
# Out:
# (10, 8)

# %%
#df = df.loc[:, ['name','runs']]
#df

df.loc[:,['name','runs']]
# Out:
#             name  runs
# 0    Anil Dalpat  6755
# 1   Rohan Kanhay  1256
# 2  Avdhoot Dighe  8954
# 3       Bahubali   756
# 4      Leeladhar  2866
# 5      Pradyumna  5877
# 6     Dinesh Roy  8537
# 7     Parmeshwar  9466
# 8    Ali Durrani  2756
# 9   Litesh Singh  1099

# %%
df2=df.loc[:,['name','runs', 'wickets']]

df3 = (df2['wickets'].sum())
df3
# Out:
# 790

# %%
avg=(df['catches'].sum())/10
avg
# Out:
# 63.3

# %%
#strike rate
strike =?

# %%
df[

# %%
df[df['stumpings'] > 0]
# Out:
#    sr.no      name  matches  runs  catches  wickets  stumpings  Month
# 3      4  Bahubali       10   756        6       11          3      5

# %%
df3 =df[df['wickets']>0]
df3
# Out:
#    sr.no          name  matches  runs  catches  wickets  stumpings  Month
# 0      1   Anil Dalpat      122  6755       56       12          0      5
# 1      2  Rohan Kanhay      144  1256       76      178          0      5
# 3      4      Bahubali       10   756        6       11          3      5
# 4      5     Leeladhar      234  2866      105      376          0      5
# 5      6     Pradyumna      177  5877       47      122          0      5
# 6      7    Dinesh Roy      211  8537      112       16          0      5
# 8      9   Ali Durrani       55  2756       12       26          0      5
# 9     10  Litesh Singh       89  1099       46       49          0      5

# %%
df3.shape
# Out:
# (8, 8)

# %%
df3['wickets'].sum()/8
# Out:
# 98.75

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x= df['matches']
x
y= df['runs']
y
# Out:
# 0    6755
# 1    1256
# 2    8954
# 3     756
# 4    2866
# 5    5877
# 6    8537
# 7    9466
# 8    2756
# 9    1099
# Name: runs, dtype: int64

# %%
plt.title('matches vs runs')
plt.xlabel('matches')
plt.ylabel('runs')
plt.grid()
plt.plot(x,y)

# %%
df.sort_values('runs')
# Out:
#    sr.no           name  matches  runs  catches  wickets  stumpings  Month
# 3      4       Bahubali       10   756        6       11          3      5
# 9     10   Litesh Singh       89  1099       46       49          0      5
# 1      2   Rohan Kanhay      144  1256       76      178          0      5
# 8      9    Ali Durrani       55  2756       12       26          0      5
# 4      5      Leeladhar      234  2866      105      376          0      5
# 5      6      Pradyumna      177  5877       47      122          0      5
# 0      1    Anil Dalpat      122  6755       56       12          0      5
# 6      7     Dinesh Roy      211  8537      112       16          0      5
# 2      3  Avdhoot Dighe      265  8954      120        0          0      5
# 7      8     Parmeshwar      245  9466       53        0          0      5

# %%
df5=df[df['wickets']>df['matches']]
df5
# Out:
#    sr.no          name  matches  runs  catches  wickets  stumpings  Month
# 1      2  Rohan Kanhay      144  1256       76      178          0      5
# 3      4      Bahubali       10   756        6       11          3      5
# 4      5     Leeladhar      234  2866      105      376          0      5
