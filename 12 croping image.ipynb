# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
## Load the image
img = plt.imread('images/lenna.png')

# %%
img.shape
# Out:
# (512, 512, 3)

# %%
img.size
# Out:
# 786432

# %%
new_img = img[150:300, 200:350]

# %%
plt.imshow(new_img)

# %%
## Load the image
img = plt.imread('images/lenna.png')

# %%
img.shape
# Out:
# (512, 512, 3)

# %%
height, width, channel = img.shape

# %%
startRow = int(height *.15)
startCol = int(width*.15)
endRow = int(height*.85)
endcol = int(width*.85)

# %%
croppedImage = img[startRow:endRow, startCol:endcol ]

# %%
x = np.array([[5,6,7], [1,2,3], [8,0,9]])
y = np.array([[2,5,8], [1,9,0], [3,2,5]])

# %%
x
# Out:
# array([[5, 6, 7],
#        [1, 2, 3],
#        [8, 0, 9]])

# %%
y
# Out:
# array([[2, 5, 8],
#        [1, 9, 0],
#        [3, 2, 5]])

# %%
z = np.hstack((x, y))+

# %%
z
# Out:
# array([[5, 6, 7, 2, 5, 8],
#        [1, 2, 3, 1, 9, 0],
#        [8, 0, 9, 3, 2, 5]])

# %%
#flip the image horizontally
flipped_horizontal = cv2.flip(img,0)

# %%
new_img = np.hstack([img,flipped_horizontal])

# %%
plt.imshow(new_img)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
## Load the image
img = plt.imread('images/lenna.png')
#define shearing factor
shear_x = 0.25 # shear along x axis
shear_y = 0.45 # shear along y axis

#create transformation matrix
M = np.array([[1, shear_x,0],
              [shear_y,1,0],
            [0,0,1]])
rows, cols = img.shape
T = np.float32([[1,0,0],[0,1,50]])
#we use warAffine to transform the image using the matrix, t
imt_translation =cv2.warpAffine(img, T, (int(col*1.5), int(rows*1.5)))
sheared_image = cv2.warpPerspective(img_translation,M, (int(col*1.5), int(rows*1.5)))

# SHOW THWE flipped IMAGE
cv2.imshow('img', sheared_image)


cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 11
#       7 #create transformation matrix
#       8 M = np.array([[1, shear_x,0],
#       9               [shear_y,1,0],
#      10             [0,0,1]])
# ---> 11 rows, cols = img.shape
#      12 T = np.float32([[1,0,0],[0,1,50]])
#      13 #we use warAffine to transform the image using the matrix, t
#
# ValueError: too many values to unpack (expected 2)

# %%
#define tranformation papramtere

tx=50
ty=100
angle = 45
scale = 1.2
shear_x = 0.3
shear_y = 0.2

# create transformation matrix

M = np.float32([[scale*np.cos(np.radians(angle)),shear_x, tx ],
                 [shear_y, scale* np.sin(np.radians(angle)),ty]])

#transformation using using warAffine
img_Affine = cv2.warpAffine(img, M, (512,512))

#DISPLAY ORIGINAL AND AFFINE TRANSFORMEDIMAGE

cv2.imshow('aFFINE TRANS IMG', img_Affine)

cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
#define tranformation papramtere

tx=50
ty=100
angle = 45
scale = 1.2
shear_x = 0.3
shear_y = 0.2

# create transformation matrix

M = np.float32([[scale*np.cos(np.radians(angle)),shear_x, tx ],
                 [shear_y, scale* np.sin(np.radians(angle)),ty]])

#transformation using using warAffine
img_Affine = cv2.warpAffine(img, M, (512,512))

#DISPLAY ORIGINAL AND AFFINE TRANSFORMEDIMAGE

final_image = np.hstack([img,img_Affine ])
cv2.imshow('aFFINE TRANS IMG', final_image)

cv2.waitKey(0)
cv2.destroyAllWindows()
