# %%
import cv2
import matplotlib.pyplot as plt

# %%
vid =cv2.VideoCapture('images/robots.mp4')

# %%
vid
# Out:
# < cv2.VideoCapture 00000238EBB87510>

# %%
ret, frame = vid.read()

# %%
ret
# Out:
# True

# %%
frame.shape
# Out:
# (640, 640, 3)

# %%
cv2.imshow('Frmae',frame)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
width = int(vid.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(vid.get(cv2.CAP_PROP_FRAME_HEIGHT))
frames = int(vid.get(cv2.CAP_PROP_FRAME_COUNT))
fps = int(vid.get(cv2.CAP_PROP_FPS))

# %%
print('Video Resolution:', height,width)
print('total Frame:', frames)
print('FPS:', fps)
# Out:
# Video Resolution: 640 640
# total Frame: 1799
# FPS: 30

# %%
vid = cv2.VideoCapture('images/robots.mp4')
while True:
    ret, frame = vid.read()
    if not ret:
        break
    # Process the frame(eg., apply filters detect objects)
    cv2.imshow('Video', frame)
    if cv2.waitKey(5) == ord('q'):
    #every frame will come after 5ms 
        break


cv2.destroyAllWindows()

# %%
vid = cv2.VideoCapture('images/robots.mp4')

#get first and see if successful
success, frmae = vid.read()
# initiate count
count = 1
# keep extracting frames as long as sucess is True
while success:
    cv2.imwrite(f'video_frames/{count}.jpg', frame)
    success, frmae = vid.read()
    count += 1

# %% [markdown]
# # to show specific image of this folder video_frames

# %%
img = cv2.imread('video_frames/200.jpg')

# %%
cv2.imshow('Image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # or using image-plot

# %%
img200 = plt.imread('video_frames/200.jpg')
plt.imshow(img200)

# %% [markdown]
# # open using PLT and show using cv2

# %%
img200 = plt.imread('video_frames/200.jpg')

# %%
cv2.imshow('Image',img200)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
timestamp ='00:00:43.00'

# %%
timestamp.split(':')
# Out:
# ['00', '00', '43.00']

# %%
# GET FRAME AT A SPECIFIC TIMESTAMP
timestamp ='00:00:43.00'
hours, minutes, seconds = [float(i) for i in timestamp.split(':')]
print(hours, minutes, seconds)
# Out:
# 0.0 0.0 43.0

# %%
# get number of frames up to timestamp
trigger_frame = hours * 3600*fps + minutes * 60 * fps + seconds * fps
print(frame, trigger_frame)
# Out:
# [[[ 23  17   7]
#   [ 23  17   7]
#   [ 23  17   7]
#   ...
#   [ 46  33  15]
#   [ 46  33  15]
#   [ 46  33  15]]
#
#  [[ 23  17   7]
#   [ 23  17   7]
#   [ 23  17   7]
#   ...
#   [ 46  33  15]
#   [ 46  33  15]
#   [ 46  33  15]]
#
#  [[ 23  17   7]
#   [ 23  17   7]
#   [ 23  17   7]
#   ...
#   [ 46  33  15]
#   [ 46  33  15]
#   [ 46  33  15]]
#
#  ...
#
#  [[169 172 185]
#   [169 172 185]
#   [169 172 185]
#   ...
#   [147 143 167]
#   [147 143 167]
#   [147 143 167]]
#
#  [[169 172 185]
#   [169 172 185]
#   [169 172 185]
#   ...
#   [147 143 167]
#   [147 143 167]
#   [147 143 167]]
#
#  [[169 172 185]
#   [169 172 185]
#   [169 172 185]
#   ...
#   [148 144 168]
#   [148 144 168]
#   [148 144 168]]] 1290.0

# %%
# go to frame selected by timestamp
vid.set(1,trigger_frame)
success, frame = vid.read()
sucess, frame = vid.read()

#save the frame into an image file
if success:
    cv2.imwrite('screen.jpg', frame)

# %%
# go to frame selected by timestamp
vid.set(1,trigger_frame+25)
success, frame = vid.read()
sucess, frame = vid.read()

#save the frame into an image file
if success:
    cv2.imwrite('screen.jpg', frame)

# %%
help(vid.set)
# Out:
# Help on built-in function set:
#
# set(...) method of cv2.VideoCapture instance
#     set(propId, value) -> retval
#     .   @brief Sets a property in the VideoCapture.
#     .
#     .       @param propId Property identifier from cv::VideoCaptureProperties (eg. cv::CAP_PROP_POS_MSEC, cv::CAP_PROP_POS_FRAMES, ...)
#     .       or one from @ref videoio_flags_others
#     .       @param value Value of the property.
#     .       @return `true` if the property is supported by backend used by the VideoCapture instance.
#     .       @note Even if it returns `true` this doesn't ensure that the property
#     .       value has been accepted by the capture device. See note in VideoCapture::get()

# %%
cap = cv2.VideoCapture(0)

# %%
cap.isOpened()
# Out:
# False

# %%
success, frame.
